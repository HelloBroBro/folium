# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d83cfe1d1208aff55285370246c5921 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d83cfe1d1208aff55285370246c5921&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d83cfe1d1208aff55285370246c5921 = L.map(
#                 &quot;map_5d83cfe1d1208aff55285370246c5921&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e43f2116f2dc0f6ef37e04a6c2ee7c27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e43f2116f2dc0f6ef37e04a6c2ee7c27.addTo(map_5d83cfe1d1208aff55285370246c5921);
#
#
#             var marker_cluster_25f37d7b3c863c091f7dec36362f04ce = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_0f70d67748b04974584c091b57469e12 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_25f37d7b3c863c091f7dec36362f04ce);
#
#
#             var icon_b41b727b5dfaeaaa0ac43f05ab470b35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0f70d67748b04974584c091b57469e12.setIcon(icon_b41b727b5dfaeaaa0ac43f05ab470b35);
#
#
#         var popup_d870adaa9a41e432414ce0c5df4a278d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c2d101ee42627ad6f97446c3edf4386 = $(`&lt;div id=&quot;html_7c2d101ee42627ad6f97446c3edf4386&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_d870adaa9a41e432414ce0c5df4a278d.setContent(html_7c2d101ee42627ad6f97446c3edf4386);
#
#
#
#         marker_0f70d67748b04974584c091b57469e12.bindPopup(popup_d870adaa9a41e432414ce0c5df4a278d)
#         ;
#
#
#
#
#             var marker_0ad78253c13dd3756c4b976752193688 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_25f37d7b3c863c091f7dec36362f04ce);
#
#
#             var icon_24fd2b907c99e4556a6c73779d0bce68 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0ad78253c13dd3756c4b976752193688.setIcon(icon_24fd2b907c99e4556a6c73779d0bce68);
#
#
#         var popup_af4ab66458fe8e59c8ae6b0ac15f4e82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5ff909fd35b920207d795d642eb8e22 = $(`&lt;div id=&quot;html_f5ff909fd35b920207d795d642eb8e22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_af4ab66458fe8e59c8ae6b0ac15f4e82.setContent(html_f5ff909fd35b920207d795d642eb8e22);
#
#
#
#         marker_0ad78253c13dd3756c4b976752193688.bindPopup(popup_af4ab66458fe8e59c8ae6b0ac15f4e82)
#         ;
#
#
#
#
#             var marker_3821432d1e651d5dd4ac47d3663dc848 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_25f37d7b3c863c091f7dec36362f04ce);
#
#
#         var popup_4098e0faf56eed3343186b631a833b74 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbd3db6bfd5a9711bcb5746633543ae2 = $(`&lt;div id=&quot;html_cbd3db6bfd5a9711bcb5746633543ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_4098e0faf56eed3343186b631a833b74.setContent(html_cbd3db6bfd5a9711bcb5746633543ae2);
#
#
#
#         marker_3821432d1e651d5dd4ac47d3663dc848.bindPopup(popup_4098e0faf56eed3343186b631a833b74)
#         ;
#
#
#
#
#             marker_cluster_25f37d7b3c863c091f7dec36362f04ce.addTo(map_5d83cfe1d1208aff55285370246c5921);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1e673a3022432eeaf7dfa9327af3268 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1e673a3022432eeaf7dfa9327af3268&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1e673a3022432eeaf7dfa9327af3268 = L.map(
#                 &quot;map_c1e673a3022432eeaf7dfa9327af3268&quot;,
#                 {
#                     center: [-5.13, 10.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_555b7421075c1472ad78bc8b9f7c9475 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_555b7421075c1472ad78bc8b9f7c9475.addTo(map_c1e673a3022432eeaf7dfa9327af3268);
#
#
#             var marker_cluster_a85c72f44baea92e23d39eeca62fa139 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_a85c72f44baea92e23d39eeca62fa139.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_1075e5f802b3ff22263dbf04b3d177bc = L.marker(
#                 [-69.0, -8.0],
#                 {}
#             ).addTo(marker_cluster_a85c72f44baea92e23d39eeca62fa139);
#
#
#         var popup_8bc05afcec0a5735379a3535d62492da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c190c24a18e10df80c42d6700421ab0a = $(`&lt;div id=&quot;html_c190c24a18e10df80c42d6700421ab0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-8&lt;br&gt;lat:-69&lt;/div&gt;`)[0];
#                 popup_8bc05afcec0a5735379a3535d62492da.setContent(html_c190c24a18e10df80c42d6700421ab0a);
#
#
#
#         marker_1075e5f802b3ff22263dbf04b3d177bc.bindPopup(popup_8bc05afcec0a5735379a3535d62492da)
#         ;
#
#
#
#
#             var marker_5ea8115997b60ef5f4868c5db5c3d268 = L.marker(
#                 [-84.0, -98.0],
#                 {}
#             ).addTo(marker_cluster_a85c72f44baea92e23d39eeca62fa139);
#
#
#         var popup_0e9e4d37410a6aef5fa40e9c90fec6cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c359016a01dba1e21702df08b6c3a9d2 = $(`&lt;div id=&quot;html_c359016a01dba1e21702df08b6c3a9d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-98&lt;br&gt;lat:-84&lt;/div&gt;`)[0];
#                 popup_0e9e4d37410a6aef5fa40e9c90fec6cc.setContent(html_c359016a01dba1e21702df08b6c3a9d2);
#
#
#
#         marker_5ea8115997b60ef5f4868c5db5c3d268.bindPopup(popup_0e9e4d37410a6aef5fa40e9c90fec6cc)
#         ;
#
#
#
#
#             var marker_c72064165527fa2261d9b97a5f73012b = L.marker(
#                 [70.0, -64.0],
#                 {}
#             ).addTo(marker_cluster_a85c72f44baea92e23d39eeca62fa139);
#
#
#         var popup_5f5d677fa2bfd4019b7dea8fd54bc91b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f256d37d47334938c14312f5b9bb58f3 = $(`&lt;div id=&quot;html_f256d37d47334938c14312f5b9bb58f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-64&lt;br&gt;lat:70&lt;/div&gt;`)[0];
#                 popup_5f5d677fa2bfd4019b7dea8fd54bc91b.setContent(html_f256d37d47334938c14312f5b9bb58f3);
#
#
#
#         marker_c72064165527fa2261d9b97a5f73012b.bindPopup(popup_5f5d677fa2bfd4019b7dea8fd54bc91b)
#         ;
#
#
#
#
#             var marker_6462ca84f30fafce05c90aac8e91c2f2 = L.marker(
#                 [1.0, 154.0],
#                 {}
#             ).addTo(marker_cluster_a85c72f44baea92e23d39eeca62fa139);
#
#
#         var popup_70373012180026bc3e21617289baa069 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1480863d61394dafd50a16e92b0033d7 = $(`&lt;div id=&quot;html_1480863d61394dafd50a16e92b0033d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:154&lt;br&gt;lat:1&lt;/div&gt;`)[0];
#                 popup_70373012180026bc3e21617289baa069.setContent(html_1480863d61394dafd50a16e92b0033d7);
#
#
#
#         marker_6462ca84f30fafce05

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af64892d8aa33c5cd92a8a0b3d555150 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af64892d8aa33c5cd92a8a0b3d555150&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af64892d8aa33c5cd92a8a0b3d555150 = L.map(
#                 &quot;map_af64892d8aa33c5cd92a8a0b3d555150&quot;,
#                 {
#                     center: [-5.13, 10.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5fa86343df7d15c7bc7b454489b8c2c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a5fa86343df7d15c7bc7b454489b8c2c.addTo(map_af64892d8aa33c5cd92a8a0b3d555150);
#
#
#             var marker_cluster_4ed81a6f386d50e893c6f74df6fa9fda = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_86a95c4c96088564bec2c68ef78feb30 = L.marker(
#                 [-69.0, -8.0],
#                 {}
#             ).addTo(marker_cluster_4ed81a6f386d50e893c6f74df6fa9fda);
#
#
#         var popup_226ca02c538d9650c4bba6cb05048ee7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc0ca31f562430a1c43e328eafc483c0 = $(`&lt;div id=&quot;html_fc0ca31f562430a1c43e328eafc483c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-8&lt;br&gt;lat:-69&lt;/div&gt;`)[0];
#                 popup_226ca02c538d9650c4bba6cb05048ee7.setContent(html_fc0ca31f562430a1c43e328eafc483c0);
#
#
#
#         marker_86a95c4c96088564bec2c68ef78feb30.bindPopup(popup_226ca02c538d9650c4bba6cb05048ee7)
#         ;
#
#
#
#
#             var marker_accf7652c5f2ac7d4c628c35722103a8 = L.marker(
#                 [-84.0, -98.0],
#                 {}
#             ).addTo(marker_cluster_4ed81a6f386d50e893c6f74df6fa9fda);
#
#
#         var popup_f567ec243c5222cb0778304a88a3134a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08cd05da2107a505de08656cf845fe92 = $(`&lt;div id=&quot;html_08cd05da2107a505de08656cf845fe92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-98&lt;br&gt;lat:-84&lt;/div&gt;`)[0];
#                 popup_f567ec243c5222cb0778304a88a3134a.setContent(html_08cd05da2107a505de08656cf845fe92);
#
#
#
#         marker_accf7652c5f2ac7d4c628c35722103a8.bindPopup(popup_f567ec243c5222cb0778304a88a3134a)
#         ;
#
#
#
#
#             var marker_bafe376496705a13a55d60d7be98e6f1 = L.marker(
#                 [70.0, -64.0],
#                 {}
#             ).addTo(marker_cluster_4ed81a6f386d50e893c6f74df6fa9fda);
#
#
#         var popup_a1274cb8a4021f7c36140bdb7edd6d2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_672ac369750de3428400f4c7741e239a = $(`&lt;div id=&quot;html_672ac369750de3428400f4c7741e239a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-64&lt;br&gt;lat:70&lt;/div&gt;`)[0];
#                 popup_a1274cb8a4021f7c36140bdb7edd6d2f.setContent(html_672ac369750de3428400f4c7741e239a);
#
#
#
#         marker_bafe376496705a13a55d60d7be98e6f1.bindPopup(popup_a1274cb8a4021f7c36140bdb7edd6d2f)
#         ;
#
#
#
#
#             var marker_e1225b61605f5e23146e8022cee6944c = L.marker(
#                 [1.0, 154.0],
#                 {}
#             ).addTo(marker_cluster_4ed81a6f386d50e893c6f74df6fa9fda);
#
#
#         var popup_d21715912cde1ae4daf1ade0249a13c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d960e1e40de10074f6590c55ad32172 = $(`&lt;div id=&quot;html_9d960e1e40de10074f6590c55ad32172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:154&lt;br&gt;lat:1&lt;/div&gt;`)[0];
#                 popup_d21715912cde1ae4daf1ade0249a13c0.setContent(html_9d960e1e40de10074f6590c55ad32172);
#
#
#
#         marker_e1225b61605f5e23146e8022cee6944c.bindPopup(popup_d21715912cde1ae4daf1ade0249a13c0)
#         ;
#
#
#
#
#             var marker_0b53e52f6fa980618e8d19a6eae680ab = L.marker(
#                 [-23.0, -41.0],
#                 {}
#             ).addTo(marker_cluster_4ed81a6f386d50e893c6f74df6fa9fda);
#
#
#         var popup_3e6b42bc7df9f1efff400b6ba

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_166ce0de22f0e78cf5a255d8d80abf38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_166ce0de22f0e78cf5a255d8d80abf38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_166ce0de22f0e78cf5a255d8d80abf38 = L.map(
#                 &quot;map_166ce0de22f0e78cf5a255d8d80abf38&quot;,
#                 {
#                     center: [-5.13, 10.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_824c85ec49d4c963ae48cffe45d2f7d3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer