# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c96bd2925e7703c7a69c4002575e8945 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c96bd2925e7703c7a69c4002575e8945&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c96bd2925e7703c7a69c4002575e8945 = L.map(
#                 &quot;map_c96bd2925e7703c7a69c4002575e8945&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fba77ac8ffa81afa2efb008ad99cc63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7fba77ac8ffa81afa2efb008ad99cc63.addTo(map_c96bd2925e7703c7a69c4002575e8945);
#
#
#             var feature_group_4d33d58d043ea9d6ae8e8e3aedecc196 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_4d33d58d043ea9d6ae8e8e3aedecc196.addTo(map_c96bd2925e7703c7a69c4002575e8945);
#
#
#             var feature_group_sub_group_050ffd3fce348943f3a49f7beb21ccd3 = L.featureGroup.subGroup(
#                 feature_group_4d33d58d043ea9d6ae8e8e3aedecc196
#             );
#
#
#             var marker_5d690b060e9ed769f0c2a32233894c1d = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_050ffd3fce348943f3a49f7beb21ccd3);
#
#
#             var marker_d8f6b88dd803a23c3c682f179e637092 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_050ffd3fce348943f3a49f7beb21ccd3);
#
#
#             feature_group_sub_group_050ffd3fce348943f3a49f7beb21ccd3.addTo(map_c96bd2925e7703c7a69c4002575e8945);
#
#
#             var feature_group_sub_group_90247d61ae3bd1fe9ff116d897011368 = L.featureGroup.subGroup(
#                 feature_group_4d33d58d043ea9d6ae8e8e3aedecc196
#             );
#
#
#             var marker_f810b4b8569ca0d4ed071eb1d424f214 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_90247d61ae3bd1fe9ff116d897011368);
#
#
#             var marker_6fa6b9f6fa356d63abd756a91d8d5318 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_90247d61ae3bd1fe9ff116d897011368);
#
#
#             feature_group_sub_group_90247d61ae3bd1fe9ff116d897011368.addTo(map_c96bd2925e7703c7a69c4002575e8945);
#
#
#             var layer_control_c9d0078c2ac9d29392f4c298cd3f8206_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7fba77ac8ffa81afa2efb008ad99cc63,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_4d33d58d043ea9d6ae8e8e3aedecc196,
#                     &quot;group1&quot; : feature_group_sub_group_050ffd3fce348943f3a49f7beb21ccd3,
#                     &quot;group2&quot; : feature_group_sub_group_90247d61ae3bd1fe9ff116d897011368,
#                 },
#             };
#             let layer_control_c9d0078c2ac9d29392f4c298cd3f8206 = L.control.layers(
#                 layer_control_c9d0078c2ac9d29392f4c298cd3f8206_layers.base_layers,
#                 layer_control_c9d0078c2ac9d29392f4c298cd3f8206_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c96bd2925e7703c7a69c4002575e8945);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17d1b3a0b00d26c00a4377a9ae1b7cad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17d1b3a0b00d26c00a4377a9ae1b7cad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17d1b3a0b00d26c00a4377a9ae1b7cad = L.map(
#                 &quot;map_17d1b3a0b00d26c00a4377a9ae1b7cad&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14c202d4d623c0fd1a5e52e52747729a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_14c202d4d623c0fd1a5e52e52747729a.addTo(map_17d1b3a0b00d26c00a4377a9ae1b7cad);
#
#
#             var marker_cluster_77af3e0340a4271939bc38bbacd89966 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_77af3e0340a4271939bc38bbacd89966.addTo(map_17d1b3a0b00d26c00a4377a9ae1b7cad);
#
#
#             var feature_group_sub_group_73871e5348e0c723d9443f2ab87932c5 = L.featureGroup.subGroup(
#                 marker_cluster_77af3e0340a4271939bc38bbacd89966
#             );
#
#
#             var marker_e8890d898ecc692e6cb986ab1e1b19c2 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_73871e5348e0c723d9443f2ab87932c5);
#
#
#             var marker_300c4e48adfbfeb8cb77c673c5bc4423 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_73871e5348e0c723d9443f2ab87932c5);
#
#
#             feature_group_sub_group_73871e5348e0c723d9443f2ab87932c5.addTo(map_17d1b3a0b00d26c00a4377a9ae1b7cad);
#
#
#             var feature_group_sub_group_4d6cfff6b39812d68cfbb93afd077eb1 = L.featureGroup.subGroup(
#                 marker_cluster_77af3e0340a4271939bc38bbacd89966
#             );
#
#
#             var marker_e17c84d031b59b64965da8916374e6ce = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4d6cfff6b39812d68cfbb93afd077eb1);
#
#
#             var marker_ae886e88f6449c7ba15ddbac76beec39 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_4d6cfff6b39812d68cfbb93afd077eb1);
#
#
#             feature_group_sub_group_4d6cfff6b39812d68cfbb93afd077eb1.addTo(map_17d1b3a0b00d26c00a4377a9ae1b7cad);
#
#
#             var layer_control_2962dc7b66bcd6b07ade62b318a5e044_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_14c202d4d623c0fd1a5e52e52747729a,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_73871e5348e0c723d9443f2ab87932c5,
#                     &quot;group2&quot; : feature_group_sub_group_4d6cfff6b39812d68cfbb93afd077eb1,
#                 },
#             };
#             let layer_control_2962dc7b66bcd6b07ade62b318a5e044 = L.control.layers(
#                 layer_control_2962dc7b66bcd6b07ade62b318a5e044_layers.base_layers,
#                 layer_control_2962dc7b66bcd6b07ade62b318a5e044_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_17d1b3a0b00d26c00a4377a9ae1b7cad);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
