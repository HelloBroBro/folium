# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54ad9ccf1a485b5d9b29d66a4dce23ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54ad9ccf1a485b5d9b29d66a4dce23ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54ad9ccf1a485b5d9b29d66a4dce23ff = L.map(
#                 &quot;map_54ad9ccf1a485b5d9b29d66a4dce23ff&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e6406d73e23c3e5ef549a1de496187f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2e6406d73e23c3e5ef549a1de496187f.addTo(map_54ad9ccf1a485b5d9b29d66a4dce23ff);
#
#
#             var feature_group_8c97498cd838c84c1598cb2623fcf15e = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_8c97498cd838c84c1598cb2623fcf15e.addTo(map_54ad9ccf1a485b5d9b29d66a4dce23ff);
#
#
#             var feature_group_sub_group_9c79560c8eea8e669ba4e8ec1cbe61c8 = L.featureGroup.subGroup(
#                 feature_group_8c97498cd838c84c1598cb2623fcf15e
#             );
#
#
#             var marker_2ee415d8975095c683a2ddb340ad22cd = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_9c79560c8eea8e669ba4e8ec1cbe61c8);
#
#
#             var marker_d23f738b4bfdc70561c3e1d54675f0a9 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_9c79560c8eea8e669ba4e8ec1cbe61c8);
#
#
#             feature_group_sub_group_9c79560c8eea8e669ba4e8ec1cbe61c8.addTo(map_54ad9ccf1a485b5d9b29d66a4dce23ff);
#
#
#             var feature_group_sub_group_5780fd1c6031bb1a386643323a2f3e65 = L.featureGroup.subGroup(
#                 feature_group_8c97498cd838c84c1598cb2623fcf15e
#             );
#
#
#             var marker_d4f8697ab6f750b1028ba99d71a46a19 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5780fd1c6031bb1a386643323a2f3e65);
#
#
#             var marker_f7236323da01a920224e17583c3e6ada = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5780fd1c6031bb1a386643323a2f3e65);
#
#
#             feature_group_sub_group_5780fd1c6031bb1a386643323a2f3e65.addTo(map_54ad9ccf1a485b5d9b29d66a4dce23ff);
#
#
#             var layer_control_478b52b0e21f464fa2e43429e42ff660_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_2e6406d73e23c3e5ef549a1de496187f,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_8c97498cd838c84c1598cb2623fcf15e,
#                     &quot;group1&quot; : feature_group_sub_group_9c79560c8eea8e669ba4e8ec1cbe61c8,
#                     &quot;group2&quot; : feature_group_sub_group_5780fd1c6031bb1a386643323a2f3e65,
#                 },
#             };
#             let layer_control_478b52b0e21f464fa2e43429e42ff660 = L.control.layers(
#                 layer_control_478b52b0e21f464fa2e43429e42ff660_layers.base_layers,
#                 layer_control_478b52b0e21f464fa2e43429e42ff660_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_54ad9ccf1a485b5d9b29d66a4dce23ff);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd56d12bea13f91b59f6f7273f36b61a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd56d12bea13f91b59f6f7273f36b61a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd56d12bea13f91b59f6f7273f36b61a = L.map(
#                 &quot;map_dd56d12bea13f91b59f6f7273f36b61a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_294cd1e9f4336cd70e57e50254de8e9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_294cd1e9f4336cd70e57e50254de8e9e.addTo(map_dd56d12bea13f91b59f6f7273f36b61a);
#
#
#             var marker_cluster_f9d69e0a7f25f813617a87dd8cdaabf2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_f9d69e0a7f25f813617a87dd8cdaabf2.addTo(map_dd56d12bea13f91b59f6f7273f36b61a);
#
#
#             var feature_group_sub_group_57e836a27a9e40003513c5d55a1a595e = L.featureGroup.subGroup(
#                 marker_cluster_f9d69e0a7f25f813617a87dd8cdaabf2
#             );
#
#
#             var marker_44f0975993d087f70d778445d7a62bce = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_57e836a27a9e40003513c5d55a1a595e);
#
#
#             var marker_bf9b559b43c95a56757eeab453cdfd5a = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_57e836a27a9e40003513c5d55a1a595e);
#
#
#             feature_group_sub_group_57e836a27a9e40003513c5d55a1a595e.addTo(map_dd56d12bea13f91b59f6f7273f36b61a);
#
#
#             var feature_group_sub_group_c7231b1a03cdc9fec190e64a40e4cc92 = L.featureGroup.subGroup(
#                 marker_cluster_f9d69e0a7f25f813617a87dd8cdaabf2
#             );
#
#
#             var marker_ae35f5bf226a38b042146a3b44cd8f47 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_c7231b1a03cdc9fec190e64a40e4cc92);
#
#
#             var marker_b8941cc7382d34c8f252a9b0f6c45baa = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_c7231b1a03cdc9fec190e64a40e4cc92);
#
#
#             feature_group_sub_group_c7231b1a03cdc9fec190e64a40e4cc92.addTo(map_dd56d12bea13f91b59f6f7273f36b61a);
#
#
#             var layer_control_a7dd57ef0c8c8e8244624eb19a947d4c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_294cd1e9f4336cd70e57e50254de8e9e,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_57e836a27a9e40003513c5d55a1a595e,
#                     &quot;group2&quot; : feature_group_sub_group_c7231b1a03cdc9fec190e64a40e4cc92,
#                 },
#             };
#             let layer_control_a7dd57ef0c8c8e8244624eb19a947d4c = L.control.layers(
#                 layer_control_a7dd57ef0c8c8e8244624eb19a947d4c_layers.base_layers,
#                 layer_control_a7dd57ef0c8c8e8244624eb19a947d4c_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_dd56d12bea13f91b59f6f7273f36b61a);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
