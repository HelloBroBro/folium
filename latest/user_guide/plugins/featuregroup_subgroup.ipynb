# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_439689d916c8e22e074a5436cf1a509a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_439689d916c8e22e074a5436cf1a509a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_439689d916c8e22e074a5436cf1a509a = L.map(
#                 &quot;map_439689d916c8e22e074a5436cf1a509a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e40d2fbfaf2e663766ad3e2b8f94daa0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e40d2fbfaf2e663766ad3e2b8f94daa0.addTo(map_439689d916c8e22e074a5436cf1a509a);
#
#
#             var feature_group_7a96ccaecb40e77fefbd14ff63c8a91c = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_7a96ccaecb40e77fefbd14ff63c8a91c.addTo(map_439689d916c8e22e074a5436cf1a509a);
#
#
#             var feature_group_sub_group_f2d8e056b017c5de168ec5e2c0c8ec5f = L.featureGroup.subGroup(
#                 feature_group_7a96ccaecb40e77fefbd14ff63c8a91c
#             );
#
#
#             var marker_1183277a93aa0f4846fd9beb13ccb2f3 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_f2d8e056b017c5de168ec5e2c0c8ec5f);
#
#
#             var marker_ed6aeac3a8246eace3c9450d509b18a3 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_f2d8e056b017c5de168ec5e2c0c8ec5f);
#
#
#             feature_group_sub_group_f2d8e056b017c5de168ec5e2c0c8ec5f.addTo(map_439689d916c8e22e074a5436cf1a509a);
#
#
#             var feature_group_sub_group_eac10aaa987e07407b0ef6f04a23f8e2 = L.featureGroup.subGroup(
#                 feature_group_7a96ccaecb40e77fefbd14ff63c8a91c
#             );
#
#
#             var marker_edb526248b95d902f539892a696b9164 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_eac10aaa987e07407b0ef6f04a23f8e2);
#
#
#             var marker_ecd4708e81b54940f37bc700d34f3f23 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_eac10aaa987e07407b0ef6f04a23f8e2);
#
#
#             feature_group_sub_group_eac10aaa987e07407b0ef6f04a23f8e2.addTo(map_439689d916c8e22e074a5436cf1a509a);
#
#
#             var layer_control_c0b082b2b4d6d02d21366c1d02275ab9_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e40d2fbfaf2e663766ad3e2b8f94daa0,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_7a96ccaecb40e77fefbd14ff63c8a91c,
#                     &quot;group1&quot; : feature_group_sub_group_f2d8e056b017c5de168ec5e2c0c8ec5f,
#                     &quot;group2&quot; : feature_group_sub_group_eac10aaa987e07407b0ef6f04a23f8e2,
#                 },
#             };
#             let layer_control_c0b082b2b4d6d02d21366c1d02275ab9 = L.control.layers(
#                 layer_control_c0b082b2b4d6d02d21366c1d02275ab9_layers.base_layers,
#                 layer_control_c0b082b2b4d6d02d21366c1d02275ab9_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_439689d916c8e22e074a5436cf1a509a);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b32eb573aa4b2e6d6faf98c239e0616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b32eb573aa4b2e6d6faf98c239e0616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b32eb573aa4b2e6d6faf98c239e0616 = L.map(
#                 &quot;map_1b32eb573aa4b2e6d6faf98c239e0616&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f167274d81740fd95430c54f756e8b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6f167274d81740fd95430c54f756e8b3.addTo(map_1b32eb573aa4b2e6d6faf98c239e0616);
#
#
#             var marker_cluster_5db98a40a03f27d0d8e4426f26f36f73 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_5db98a40a03f27d0d8e4426f26f36f73.addTo(map_1b32eb573aa4b2e6d6faf98c239e0616);
#
#
#             var feature_group_sub_group_3288f90ae359ece1edd5cda24af7be4d = L.featureGroup.subGroup(
#                 marker_cluster_5db98a40a03f27d0d8e4426f26f36f73
#             );
#
#
#             var marker_8fec447218f1862538e381952710f59b = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3288f90ae359ece1edd5cda24af7be4d);
#
#
#             var marker_65ada813474d1b926287f26cd6cef11d = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3288f90ae359ece1edd5cda24af7be4d);
#
#
#             feature_group_sub_group_3288f90ae359ece1edd5cda24af7be4d.addTo(map_1b32eb573aa4b2e6d6faf98c239e0616);
#
#
#             var feature_group_sub_group_a0619c31b3b9df40994ab0d2f1e0a36d = L.featureGroup.subGroup(
#                 marker_cluster_5db98a40a03f27d0d8e4426f26f36f73
#             );
#
#
#             var marker_a01f21da03234205fb0eb201669ee9c0 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_a0619c31b3b9df40994ab0d2f1e0a36d);
#
#
#             var marker_81fcacd71207d17ad7f2f262d07e9694 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_a0619c31b3b9df40994ab0d2f1e0a36d);
#
#
#             feature_group_sub_group_a0619c31b3b9df40994ab0d2f1e0a36d.addTo(map_1b32eb573aa4b2e6d6faf98c239e0616);
#
#
#             var layer_control_1e918d4660157e0c935193b2c629afda_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_6f167274d81740fd95430c54f756e8b3,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_3288f90ae359ece1edd5cda24af7be4d,
#                     &quot;group2&quot; : feature_group_sub_group_a0619c31b3b9df40994ab0d2f1e0a36d,
#                 },
#             };
#             let layer_control_1e918d4660157e0c935193b2c629afda = L.control.layers(
#                 layer_control_1e918d4660157e0c935193b2c629afda_layers.base_layers,
#                 layer_control_1e918d4660157e0c935193b2c629afda_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_1b32eb573aa4b2e6d6faf98c239e0616);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
