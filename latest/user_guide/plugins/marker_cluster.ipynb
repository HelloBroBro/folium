# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb9181f73638d662b03fa65e55b19db1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb9181f73638d662b03fa65e55b19db1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb9181f73638d662b03fa65e55b19db1 = L.map(
#                 &quot;map_cb9181f73638d662b03fa65e55b19db1&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f3a6dd1d1c9ba8820a004bac78192a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8f3a6dd1d1c9ba8820a004bac78192a5.addTo(map_cb9181f73638d662b03fa65e55b19db1);
#
#
#             var marker_cluster_348252a3531ee652aea2e2ed52c16b82 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_afe6fbd764951c0eb043b8d6df8c3e91 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_348252a3531ee652aea2e2ed52c16b82);
#
#
#             var icon_e294beaae9265263f100dc4131a74f1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_afe6fbd764951c0eb043b8d6df8c3e91.setIcon(icon_e294beaae9265263f100dc4131a74f1c);
#
#
#         var popup_afdeb40fe932cb1ac73cd1df7c42f827 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12bd3732de31f05cf42e7984a96f6394 = $(`&lt;div id=&quot;html_12bd3732de31f05cf42e7984a96f6394&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_afdeb40fe932cb1ac73cd1df7c42f827.setContent(html_12bd3732de31f05cf42e7984a96f6394);
#
#
#
#         marker_afe6fbd764951c0eb043b8d6df8c3e91.bindPopup(popup_afdeb40fe932cb1ac73cd1df7c42f827)
#         ;
#
#
#
#
#             var marker_d1d295f30c9d7ec662c11fcb60cbf09e = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_348252a3531ee652aea2e2ed52c16b82);
#
#
#             var icon_4773b3a103f203f29bd6230b36e05ffc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1d295f30c9d7ec662c11fcb60cbf09e.setIcon(icon_4773b3a103f203f29bd6230b36e05ffc);
#
#
#         var popup_6018da08eb9a663636c357df78373e27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b33fa20f259922506d0a95715e2d851a = $(`&lt;div id=&quot;html_b33fa20f259922506d0a95715e2d851a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6018da08eb9a663636c357df78373e27.setContent(html_b33fa20f259922506d0a95715e2d851a);
#
#
#
#         marker_d1d295f30c9d7ec662c11fcb60cbf09e.bindPopup(popup_6018da08eb9a663636c357df78373e27)
#         ;
#
#
#
#
#             var marker_6d0eb77878a68a8c5cadc97be8c6d5a4 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_348252a3531ee652aea2e2ed52c16b82);
#
#
#         var popup_738ab8a10d74d405926de3d5bcb0adf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d33b1c55e796603d73d882446e05912 = $(`&lt;div id=&quot;html_9d33b1c55e796603d73d882446e05912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_738ab8a10d74d405926de3d5bcb0adf9.setContent(html_9d33b1c55e796603d73d882446e05912);
#
#
#
#         marker_6d0eb77878a68a8c5cadc97be8c6d5a4.bindPopup(popup_738ab8a10d74d405926de3d5bcb0adf9)
#         ;
#
#
#
#
#             marker_cluster_348252a3531ee652aea2e2ed52c16b82.addTo(map_cb9181f73638d662b03fa65e55b19db1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6850c817ed85449f22b49eac5cb7dd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6850c817ed85449f22b49eac5cb7dd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6850c817ed85449f22b49eac5cb7dd1 = L.map(
#                 &quot;map_a6850c817ed85449f22b49eac5cb7dd1&quot;,
#                 {
#                     center: [2.35, 10.16],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e849e5d7d4f6867f8dd6a447f473d50d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e849e5d7d4f6867f8dd6a447f473d50d.addTo(map_a6850c817ed85449f22b49eac5cb7dd1);
#
#
#             var marker_cluster_846cede5669831d4b4cc82cfd153f2f7 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_846cede5669831d4b4cc82cfd153f2f7.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_9fa293766a6712fc9cd25e4498c2bccc = L.marker(
#                 [64.0, -64.0],
#                 {}
#             ).addTo(marker_cluster_846cede5669831d4b4cc82cfd153f2f7);
#
#
#         var popup_d803641ffe652084814cd58c751fbd52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9fdedaf53dece9a7842950461c138295 = $(`&lt;div id=&quot;html_9fdedaf53dece9a7842950461c138295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-64&lt;br&gt;lat:64&lt;/div&gt;`)[0];
#                 popup_d803641ffe652084814cd58c751fbd52.setContent(html_9fdedaf53dece9a7842950461c138295);
#
#
#
#         marker_9fa293766a6712fc9cd25e4498c2bccc.bindPopup(popup_d803641ffe652084814cd58c751fbd52)
#         ;
#
#
#
#
#             var marker_7cc35b9cc6f8b42eefcf6f08dff2fc44 = L.marker(
#                 [-12.0, -34.0],
#                 {}
#             ).addTo(marker_cluster_846cede5669831d4b4cc82cfd153f2f7);
#
#
#         var popup_000ea7934b781f218fd2e7123c7971d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdbdd655c5c2d543bfe08cf7d4fa2b5c = $(`&lt;div id=&quot;html_fdbdd655c5c2d543bfe08cf7d4fa2b5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-34&lt;br&gt;lat:-12&lt;/div&gt;`)[0];
#                 popup_000ea7934b781f218fd2e7123c7971d7.setContent(html_fdbdd655c5c2d543bfe08cf7d4fa2b5c);
#
#
#
#         marker_7cc35b9cc6f8b42eefcf6f08dff2fc44.bindPopup(popup_000ea7934b781f218fd2e7123c7971d7)
#         ;
#
#
#
#
#             var marker_f9c77945a2ae78512a830f565c514f9e = L.marker(
#                 [-34.0, -10.0],
#                 {}
#             ).addTo(marker_cluster_846cede5669831d4b4cc82cfd153f2f7);
#
#
#         var popup_bd93714c2a072ecb528f5f9d61bfea43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_500fecd72e716a8b5144b2ce59a50aa9 = $(`&lt;div id=&quot;html_500fecd72e716a8b5144b2ce59a50aa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-10&lt;br&gt;lat:-34&lt;/div&gt;`)[0];
#                 popup_bd93714c2a072ecb528f5f9d61bfea43.setContent(html_500fecd72e716a8b5144b2ce59a50aa9);
#
#
#
#         marker_f9c77945a2ae78512a830f565c514f9e.bindPopup(popup_bd93714c2a072ecb528f5f9d61bfea43)
#         ;
#
#
#
#
#             var marker_dd8598c1818a25bfbdb6ad05cc859254 = L.marker(
#                 [30.0, 70.0],
#                 {}
#             ).addTo(marker_cluster_846cede5669831d4b4cc82cfd153f2f7);
#
#
#         var popup_57e53619c46db47f8aa99486cc1d12db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41e08f595e34cac31ae1f5f69dd04d37 = $(`&lt;div id=&quot;html_41e08f595e34cac31ae1f5f69dd04d37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:70&lt;br&gt;lat:30&lt;/div&gt;`)[0];
#                 popup_57e53619c46db47f8aa99486cc1d12db.setContent(html_41e08f595e34cac31ae1f5f69dd04d37);
#
#
#
#         marker_dd8598c1818a25bfbdb6ad05

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68cce402a2ca4400536ac18d91332093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68cce402a2ca4400536ac18d91332093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68cce402a2ca4400536ac18d91332093 = L.map(
#                 &quot;map_68cce402a2ca4400536ac18d91332093&quot;,
#                 {
#                     center: [2.35, 10.16],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bca6d173a4db55fa4c5ea560de08b8e7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bca6d173a4db55fa4c5ea560de08b8e7.addTo(map_68cce402a2ca4400536ac18d91332093);
#
#
#             var marker_cluster_b3ee99d532bf52d00b1244d5fd00e26e = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_521f1adaeea0320b4b4a6d7d2b21f7f1 = L.marker(
#                 [64.0, -64.0],
#                 {}
#             ).addTo(marker_cluster_b3ee99d532bf52d00b1244d5fd00e26e);
#
#
#         var popup_29d0cc38127a84ac85479bbccda9528b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aed1548f77b41c5fa700203df85c3973 = $(`&lt;div id=&quot;html_aed1548f77b41c5fa700203df85c3973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-64&lt;br&gt;lat:64&lt;/div&gt;`)[0];
#                 popup_29d0cc38127a84ac85479bbccda9528b.setContent(html_aed1548f77b41c5fa700203df85c3973);
#
#
#
#         marker_521f1adaeea0320b4b4a6d7d2b21f7f1.bindPopup(popup_29d0cc38127a84ac85479bbccda9528b)
#         ;
#
#
#
#
#             var marker_c3f25ff24551bc6e9d3236d77a54c6b1 = L.marker(
#                 [-12.0, -34.0],
#                 {}
#             ).addTo(marker_cluster_b3ee99d532bf52d00b1244d5fd00e26e);
#
#
#         var popup_cc16625f37eb73b66647037c0509b484 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8382049a53fc2238c7edf7199f44db6b = $(`&lt;div id=&quot;html_8382049a53fc2238c7edf7199f44db6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-34&lt;br&gt;lat:-12&lt;/div&gt;`)[0];
#                 popup_cc16625f37eb73b66647037c0509b484.setContent(html_8382049a53fc2238c7edf7199f44db6b);
#
#
#
#         marker_c3f25ff24551bc6e9d3236d77a54c6b1.bindPopup(popup_cc16625f37eb73b66647037c0509b484)
#         ;
#
#
#
#
#             var marker_a2f4e76a1405b3728178f956f2987592 = L.marker(
#                 [-34.0, -10.0],
#                 {}
#             ).addTo(marker_cluster_b3ee99d532bf52d00b1244d5fd00e26e);
#
#
#         var popup_3d92b7ff208887f89b49f467a34cfa61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67b45381420578e4bdb77b030a70719b = $(`&lt;div id=&quot;html_67b45381420578e4bdb77b030a70719b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-10&lt;br&gt;lat:-34&lt;/div&gt;`)[0];
#                 popup_3d92b7ff208887f89b49f467a34cfa61.setContent(html_67b45381420578e4bdb77b030a70719b);
#
#
#
#         marker_a2f4e76a1405b3728178f956f2987592.bindPopup(popup_3d92b7ff208887f89b49f467a34cfa61)
#         ;
#
#
#
#
#             var marker_aad6f1e6c3c63b9fdc72c7a0789f6e51 = L.marker(
#                 [30.0, 70.0],
#                 {}
#             ).addTo(marker_cluster_b3ee99d532bf52d00b1244d5fd00e26e);
#
#
#         var popup_a274ddf046ead7b2d541691c2cf72e5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_212d5eabb88d1f941d90b664d442ba95 = $(`&lt;div id=&quot;html_212d5eabb88d1f941d90b664d442ba95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:70&lt;br&gt;lat:30&lt;/div&gt;`)[0];
#                 popup_a274ddf046ead7b2d541691c2cf72e5d.setContent(html_212d5eabb88d1f941d90b664d442ba95);
#
#
#
#         marker_aad6f1e6c3c63b9fdc72c7a0789f6e51.bindPopup(popup_a274ddf046ead7b2d541691c2cf72e5d)
#         ;
#
#
#
#
#             var marker_dc74bf95ef1cfa108870a7860bebf12c = L.marker(
#                 [-68.0, -16.0],
#                 {}
#             ).addTo(marker_cluster_b3ee99d532bf52d00b1244d5fd00e26e);
#
#
#         var popup_616c5a243b13cc952cc86eac58b73af

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0d8fa2a15ad65ac016c8be48ca770fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0d8fa2a15ad65ac016c8be48ca770fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0d8fa2a15ad65ac016c8be48ca770fa = L.map(
#                 &quot;map_f0d8fa2a15ad65ac016c8be48ca770fa&quot;,
#                 {
#                     center: [2.35, 10.16],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8