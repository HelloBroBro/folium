# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07db545548d0d74b51d821d19545d1a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07db545548d0d74b51d821d19545d1a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07db545548d0d74b51d821d19545d1a1 = L.map(
#                 &quot;map_07db545548d0d74b51d821d19545d1a1&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_369c0b51bfc3a4dc7090dd9c15e2c266 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_369c0b51bfc3a4dc7090dd9c15e2c266.addTo(map_07db545548d0d74b51d821d19545d1a1);
#
#
#             var marker_cluster_ef576cdad7d4d6b0de38b566ede5fd15 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_cb7b766d3723146af61c3cc15531a0ad = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_ef576cdad7d4d6b0de38b566ede5fd15);
#
#
#             var icon_c59251d5325a894f3c2432b28fd47604 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cb7b766d3723146af61c3cc15531a0ad.setIcon(icon_c59251d5325a894f3c2432b28fd47604);
#
#
#         var popup_fec80954da1a63fde0d4c891af42d3c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02e34ad521add5315900e39b8202382a = $(`&lt;div id=&quot;html_02e34ad521add5315900e39b8202382a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fec80954da1a63fde0d4c891af42d3c7.setContent(html_02e34ad521add5315900e39b8202382a);
#
#
#
#         marker_cb7b766d3723146af61c3cc15531a0ad.bindPopup(popup_fec80954da1a63fde0d4c891af42d3c7)
#         ;
#
#
#
#
#             var marker_42e526b7c14186039a37590d534966c7 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_ef576cdad7d4d6b0de38b566ede5fd15);
#
#
#             var icon_cbd96dbd2fa269bdf89851e14814a0d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_42e526b7c14186039a37590d534966c7.setIcon(icon_cbd96dbd2fa269bdf89851e14814a0d9);
#
#
#         var popup_e10f8dab18786dde5bb903240c1cb852 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c5ef33b1c1f23b1686b86cdf7d717ab = $(`&lt;div id=&quot;html_1c5ef33b1c1f23b1686b86cdf7d717ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e10f8dab18786dde5bb903240c1cb852.setContent(html_1c5ef33b1c1f23b1686b86cdf7d717ab);
#
#
#
#         marker_42e526b7c14186039a37590d534966c7.bindPopup(popup_e10f8dab18786dde5bb903240c1cb852)
#         ;
#
#
#
#
#             var marker_4bb9fea4c9b8421706cc4cd682bcf008 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_ef576cdad7d4d6b0de38b566ede5fd15);
#
#
#         var popup_0b9eae894081953e29f0f8bde35abe61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_519ecfcec2c86de2aa98755bf21ef87a = $(`&lt;div id=&quot;html_519ecfcec2c86de2aa98755bf21ef87a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_0b9eae894081953e29f0f8bde35abe61.setContent(html_519ecfcec2c86de2aa98755bf21ef87a);
#
#
#
#         marker_4bb9fea4c9b8421706cc4cd682bcf008.bindPopup(popup_0b9eae894081953e29f0f8bde35abe61)
#         ;
#
#
#
#
#             marker_cluster_ef576cdad7d4d6b0de38b566ede5fd15.addTo(map_07db545548d0d74b51d821d19545d1a1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfb8491ef5b15a4e6ee2b4e718ef5b97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfb8491ef5b15a4e6ee2b4e718ef5b97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfb8491ef5b15a4e6ee2b4e718ef5b97 = L.map(
#                 &quot;map_cfb8491ef5b15a4e6ee2b4e718ef5b97&quot;,
#                 {
#                     center: [5.98, 7.75],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afc0b11e17aa98751af60113a61b3580 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_afc0b11e17aa98751af60113a61b3580.addTo(map_cfb8491ef5b15a4e6ee2b4e718ef5b97);
#
#
#             var marker_cluster_147a5c99e1c86eed6e1c4448026f4c59 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_147a5c99e1c86eed6e1c4448026f4c59.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_67c7af7f4cf75906210b50861ca1da59 = L.marker(
#                 [71.0, -11.0],
#                 {}
#             ).addTo(marker_cluster_147a5c99e1c86eed6e1c4448026f4c59);
#
#
#         var popup_14f77941b333c7ef3e7189591085569c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3720e310a15f72349e5fc0d9b3048158 = $(`&lt;div id=&quot;html_3720e310a15f72349e5fc0d9b3048158&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-11&lt;br&gt;lat:71&lt;/div&gt;`)[0];
#                 popup_14f77941b333c7ef3e7189591085569c.setContent(html_3720e310a15f72349e5fc0d9b3048158);
#
#
#
#         marker_67c7af7f4cf75906210b50861ca1da59.bindPopup(popup_14f77941b333c7ef3e7189591085569c)
#         ;
#
#
#
#
#             var marker_dd70f478d9a9fc2bf5bdb234642205fd = L.marker(
#                 [-15.0, 19.0],
#                 {}
#             ).addTo(marker_cluster_147a5c99e1c86eed6e1c4448026f4c59);
#
#
#         var popup_b1b713234de87a66ebd7913a5ba908ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bda815e9cbd685f08cea8c34e1c4bd8 = $(`&lt;div id=&quot;html_2bda815e9cbd685f08cea8c34e1c4bd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:19&lt;br&gt;lat:-15&lt;/div&gt;`)[0];
#                 popup_b1b713234de87a66ebd7913a5ba908ad.setContent(html_2bda815e9cbd685f08cea8c34e1c4bd8);
#
#
#
#         marker_dd70f478d9a9fc2bf5bdb234642205fd.bindPopup(popup_b1b713234de87a66ebd7913a5ba908ad)
#         ;
#
#
#
#
#             var marker_5dd1083f1f59fe6f4b96dbb9345fb59d = L.marker(
#                 [5.0, 101.0],
#                 {}
#             ).addTo(marker_cluster_147a5c99e1c86eed6e1c4448026f4c59);
#
#
#         var popup_9251cf0c231970072894a50598f6c27c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7979cf565342e13f8437d71a0a37a134 = $(`&lt;div id=&quot;html_7979cf565342e13f8437d71a0a37a134&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:101&lt;br&gt;lat:5&lt;/div&gt;`)[0];
#                 popup_9251cf0c231970072894a50598f6c27c.setContent(html_7979cf565342e13f8437d71a0a37a134);
#
#
#
#         marker_5dd1083f1f59fe6f4b96dbb9345fb59d.bindPopup(popup_9251cf0c231970072894a50598f6c27c)
#         ;
#
#
#
#
#             var marker_63438470fa8aab5e87b41abb20afa619 = L.marker(
#                 [20.0, 116.0],
#                 {}
#             ).addTo(marker_cluster_147a5c99e1c86eed6e1c4448026f4c59);
#
#
#         var popup_c6441c46d19fd671e2fe4a6b8923df4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f41dd8ac9d82fdcd5353dde9b831711 = $(`&lt;div id=&quot;html_4f41dd8ac9d82fdcd5353dde9b831711&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:116&lt;br&gt;lat:20&lt;/div&gt;`)[0];
#                 popup_c6441c46d19fd671e2fe4a6b8923df4d.setContent(html_4f41dd8ac9d82fdcd5353dde9b831711);
#
#
#
#         marker_63438470fa8aab5e87b41a

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24e5dbabfba6e7c7c08f8a7f576855d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24e5dbabfba6e7c7c08f8a7f576855d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24e5dbabfba6e7c7c08f8a7f576855d6 = L.map(
#                 &quot;map_24e5dbabfba6e7c7c08f8a7f576855d6&quot;,
#                 {
#                     center: [5.98, 7.75],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_764631ee9a58cf41984cb692a06ba80b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_764631ee9a58cf41984cb692a06ba80b.addTo(map_24e5dbabfba6e7c7c08f8a7f576855d6);
#
#
#             var marker_cluster_fa6d3e9abb04cfd482cf16eedac94d75 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_c17a694aa46404ddd04ce0940060c505 = L.marker(
#                 [71.0, -11.0],
#                 {}
#             ).addTo(marker_cluster_fa6d3e9abb04cfd482cf16eedac94d75);
#
#
#         var popup_6cb357ccb7d04bcc355e82afb1f84ae6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_922abdc0cb946cb539159871a3f49621 = $(`&lt;div id=&quot;html_922abdc0cb946cb539159871a3f49621&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-11&lt;br&gt;lat:71&lt;/div&gt;`)[0];
#                 popup_6cb357ccb7d04bcc355e82afb1f84ae6.setContent(html_922abdc0cb946cb539159871a3f49621);
#
#
#
#         marker_c17a694aa46404ddd04ce0940060c505.bindPopup(popup_6cb357ccb7d04bcc355e82afb1f84ae6)
#         ;
#
#
#
#
#             var marker_b884fcd53e27ccae8fc64c7723a68b52 = L.marker(
#                 [-15.0, 19.0],
#                 {}
#             ).addTo(marker_cluster_fa6d3e9abb04cfd482cf16eedac94d75);
#
#
#         var popup_7d6fea4809fd877deee15048b3e8d2b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a09afa0305ecca9f65c7593f5be2d03 = $(`&lt;div id=&quot;html_8a09afa0305ecca9f65c7593f5be2d03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:19&lt;br&gt;lat:-15&lt;/div&gt;`)[0];
#                 popup_7d6fea4809fd877deee15048b3e8d2b7.setContent(html_8a09afa0305ecca9f65c7593f5be2d03);
#
#
#
#         marker_b884fcd53e27ccae8fc64c7723a68b52.bindPopup(popup_7d6fea4809fd877deee15048b3e8d2b7)
#         ;
#
#
#
#
#             var marker_aa0b88844dca3bc1775d86a207d05e78 = L.marker(
#                 [5.0, 101.0],
#                 {}
#             ).addTo(marker_cluster_fa6d3e9abb04cfd482cf16eedac94d75);
#
#
#         var popup_d24cd560734306c6f315bb593db22f31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3bf772f3cd7455e37c1c2cfc1e43bb7d = $(`&lt;div id=&quot;html_3bf772f3cd7455e37c1c2cfc1e43bb7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:101&lt;br&gt;lat:5&lt;/div&gt;`)[0];
#                 popup_d24cd560734306c6f315bb593db22f31.setContent(html_3bf772f3cd7455e37c1c2cfc1e43bb7d);
#
#
#
#         marker_aa0b88844dca3bc1775d86a207d05e78.bindPopup(popup_d24cd560734306c6f315bb593db22f31)
#         ;
#
#
#
#
#             var marker_a1c9433516543f1e279ca9f5321b1b7b = L.marker(
#                 [20.0, 116.0],
#                 {}
#             ).addTo(marker_cluster_fa6d3e9abb04cfd482cf16eedac94d75);
#
#
#         var popup_6f26260b85fa399ee96aea752568b14a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c53b1293433bef0d9fd89e47f2956d2c = $(`&lt;div id=&quot;html_c53b1293433bef0d9fd89e47f2956d2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:116&lt;br&gt;lat:20&lt;/div&gt;`)[0];
#                 popup_6f26260b85fa399ee96aea752568b14a.setContent(html_c53b1293433bef0d9fd89e47f2956d2c);
#
#
#
#         marker_a1c9433516543f1e279ca9f5321b1b7b.bindPopup(popup_6f26260b85fa399ee96aea752568b14a)
#         ;
#
#
#
#
#             var marker_d4e6ba4469867872138567c34b1526f9 = L.marker(
#                 [52.0, 124.0],
#                 {}
#             ).addTo(marker_cluster_fa6d3e9abb04cfd482cf16eedac94d75);
#
#
#         var popup_b72df9e0aefa128147ff545f20478f

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8eafe59d1f397a9d63bf8929d61b9b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8eafe59d1f397a9d63bf8929d61b9b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8eafe59d1f397a9d63bf8929d61b9b6 = L.map(
#                 &quot;map_e8eafe59d1f397a9d63bf8929d61b9b6&quot;,
#                 {
#                     center: [5.98, 7.75],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_603f3539dfba9ef477c64f0bf9338bf9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_603f3539dfba9ef477c64f0bf9338bf9.addTo(map_e8eafe59d1f397a9d63bf8929d61b9b6);
#
#
#             var fast_marker_cluster_bf3d592a39cfc3775cbaace2c7d09240 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[71.0, -11.0], [-15.0, 19.0], [5.0, 101.0], [20.0, 116.0], [52.0, 124.0], [85.0, 118.0], [87.0, 62.0], [-16.0, 161.0], [59.0, 135.0], [-6.0, -69.0], [37.0, -180.0], [-33.0, -166.0], [-5.0, -38.0], [15.0, 75.0], [12.0, -39.0], [25.0, 8.0], [82.0, -27.0], [10.0, 43.0], [-43.0, 167.0], [36.0, 63.0], [-2.0, -91.0], [-71.0, 9.0], [-31.0, -77.0], [-15.0, 123.0], [56.0, 32.0], [-73.0, 78.0], [45.0, -148.0], [-11.0, 83.0], [59.0, -25.0], [-4.0, 103.0], [-33.0, 66.0], [-59.0, -26.0], [74.0, 178.0], [14.0, -150.0], [-6.0, 6.0], [72.0, -38.0], [7.0, 115.0], [-33.0, 7.0], [-29.0, -162.0], [76.0, -56.0], [-86.0, 170.0], [-30.0, 35.0], [84.0, 166.0], [61.0, -83.0], [30.0, -156.0], [-52.0, -28.0], [80.0, -27.0], [63.0, -154.0], [87.0, 168.0], [-48.0, -110.0], [71.0, -149.0], [82.0, 94.0], [69.0, 58.0], [-20.0, 121.0], [-24.0, 76.0], [42.0, -171.0], [-82.0, -9.0], [-82.0, 117.0], [87.0, -18.0], [24.0, 21.0], [-18.0, 86.0], [5.0, -88.0], [-69.0, 95.0], [-78.0, 51.0], [-52.0, -135.0], [4.0, 104.0], [-85.0, -110.0], [-64.0, 165.0], [24.0, -41.0], [24.0, 29.0], [66.0, 136.0], [50.0, -79.0], [-50.0, -107.0], [-67.0, -130.0], [82.0, 166.0], [-36.0, 67.0], [-76.0, -103.0], [69.0, -70.0], [65.0, -26.0], [7.0, -138.0], [61.0, 4.0], [-26.0, 149.0], [60.0, 55.0], [52.0, 11.0], [-59.0, -58.0], [-90.0, -122.0], [42.0, -15.0], [-29.0, 52.0], [-83.0, 51.0], [-49.0, -122.0], [67.0, -27.0], [17.0, -8.0], [63.0, 10.0], [51.0, 136.0], [-74.0, 14.0], [-62.0, 121.0], [-13.0, -131.0], [27.0, 36.0], [43.0, 93.0], [-71.0, -156.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_e8eafe59d1f397a9d63bf8929d61b9b6);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_bf3d592a39cfc3775cbaace2c7d09240.addTo(map_e8eafe59d1f397a9d63bf8929d61b9b6);
#
#
#             var layer_control_bd263a8936e056940b6220784cf9d135_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_603f3539dfba9ef477c64f0bf9338bf9,
#                 },
#                 overlays :  {
#                     &quot;macro_element_bf3d592a39cfc3775cbaace2c7d09240&quot; : fast_marker_cluster_bf3d592a39cfc3775cbaace2c7d09240,
#                 },
#             };
#             let layer_control_bd263a8936e056940b6220784cf9d135 = L.control.layers(
#                 layer_control_bd263a8936e056940b6220784cf9d135_layers.base_layers,
#                 layer_control_bd263a8936e056940b6220784cf9d135_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_e8eafe59d1f397a9d63bf8929d61b9b6);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_588e384330eaf2d0ab2e57b9f75ea257 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_588e384330eaf2d0ab2e57b9f75ea257&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_588e384330eaf2d0ab2e57b9f75ea257 = L.map(
#                 &quot;map_588e384330eaf2d0ab2e57b9f75ea257&quot;,
#                 {
#                     center: [5.98, 7.75],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d76dc84c35db917cca154a19374c93be = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d76dc84c35db917cca154a19374c93be.addTo(map_588e384330eaf2d0ab2e57b9f75ea257);
#
#
#             var fast_marker_cluster_dcefdcc01d59015c2e6e849eadbb9eee = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[71.0, -11.0], [-15.0, 19.0], [5.0, 101.0], [20.0, 116.0], [52.0, 124.0], [85.0, 118.0], [87.0, 62.0], [-16.0, 161.0], [59.0, 135.0], [-6.0, -69.0], [37.0, -180.0], [-33.0, -166.0], [-5.0, -38.0], [15.0, 75.0], [12.0, -39.0], [25.0, 8.0], [82.0, -27.0], [10.0, 43.0], [-43.0, 167.0], [36.0, 63.0], [-2.0, -91.0], [-71.0, 9.0], [-31.0, -77.0], [-15.0, 123.0], [56.0, 32.0], [-73.0, 78.0], [45.0, -148.0], [-11.0, 83.0], [59.0, -25.0], [-4.0, 103.0], [-33.0, 66.0], [-59.0, -26.0], [74.0, 178.0], [14.0, -150.0], [-6.0, 6.0], [72.0, -38.0], [7.0, 115.0], [-33.0, 7.0], [-29.0, -162.0], [76.0, -56.0], [-86.0, 170.0], [-30.0, 35.0], [84.0, 166.0], [61.0, -83.0], [30.0, -156.0], [-52.0, -28.0], [80.0, -27.0], [63.0, -154.0], [87.0, 168.0], [-48.0, -110.0], [71.0, -149.0], [82.0, 94.0], [69.0, 58.0], [-20.0, 121.0], [-24.0, 76.0], [42.0, -171.0], [-82.0, -9.0], [-82.0, 117.0], [87.0, -18.0], [24.0, 21.0], [-18.0, 86.0], [5.0, -88.0], [-69.0, 95.0], [-78.0, 51.0], [-52.0, -135.0], [4.0, 104.0], [-85.0, -110.0], [-64.0, 165.0], [24.0, -41.0], [24.0, 29.0], [66.0, 136.0], [50.0, -79.0], [-50.0, -107.0], [-67.0, -130.0], [82.0, 166.0], [-36.0, 67.0], [-76.0, -103.0], [69.0, -70.0], [65.0, -26.0], [7.0, -138.0], [61.0, 4.0], [-26.0, 149.0], [60.0, 55.0], [52.0, 11.0], [-59.0, -58.0], [-90.0, -122.0], [42.0, -15.0], [-29.0, 52.0], [-83.0, 51.0], [-49.0, -122.0], [67.0, -27.0], [17.0, -8.0], [63.0, 10.0], [51.0, 136.0], [-74.0, 14.0], [-62.0, 121.0], [-13.0, -131.0], [27.0, 36.0], [43.0, 93.0], [-71.0, -156.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_588e384330eaf2d0ab2e57b9f75ea257);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_dcefdcc01d59015c2e6e849eadbb9eee.addTo(map_588e384330eaf2d0ab2e57b9f75ea257);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
