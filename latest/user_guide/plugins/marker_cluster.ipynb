# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8d4cbceb1abb5f182ad74b38ec9658c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8d4cbceb1abb5f182ad74b38ec9658c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8d4cbceb1abb5f182ad74b38ec9658c = L.map(
#                 &quot;map_e8d4cbceb1abb5f182ad74b38ec9658c&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebf2b8537a7b9ce288381016bf0d5961 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ebf2b8537a7b9ce288381016bf0d5961.addTo(map_e8d4cbceb1abb5f182ad74b38ec9658c);
#
#
#             var marker_cluster_259ccda3c4d018396226a94d3ce98438 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_5547943a2a8b422436207e66a07665cc = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_259ccda3c4d018396226a94d3ce98438);
#
#
#             var icon_74887d5c4689241520e7ad3c39987ba8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5547943a2a8b422436207e66a07665cc.setIcon(icon_74887d5c4689241520e7ad3c39987ba8);
#
#
#         var popup_741be17c175629109eeafe47f06410de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9d590cb3986e4cb0e0a559e947543af = $(`&lt;div id=&quot;html_b9d590cb3986e4cb0e0a559e947543af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_741be17c175629109eeafe47f06410de.setContent(html_b9d590cb3986e4cb0e0a559e947543af);
#
#
#
#         marker_5547943a2a8b422436207e66a07665cc.bindPopup(popup_741be17c175629109eeafe47f06410de)
#         ;
#
#
#
#
#             var marker_1128440c329ca1df9c174b55934d4012 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_259ccda3c4d018396226a94d3ce98438);
#
#
#             var icon_672a9bbe49eb7e421e6e56fd747d65be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1128440c329ca1df9c174b55934d4012.setIcon(icon_672a9bbe49eb7e421e6e56fd747d65be);
#
#
#         var popup_3d3e9684190e49b57d78ef4fe6260087 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79b18fe6e810485df3a68ff9e024fff0 = $(`&lt;div id=&quot;html_79b18fe6e810485df3a68ff9e024fff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_3d3e9684190e49b57d78ef4fe6260087.setContent(html_79b18fe6e810485df3a68ff9e024fff0);
#
#
#
#         marker_1128440c329ca1df9c174b55934d4012.bindPopup(popup_3d3e9684190e49b57d78ef4fe6260087)
#         ;
#
#
#
#
#             var marker_e80fdd4f7b9692c6903c94dd756e4ae9 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_259ccda3c4d018396226a94d3ce98438);
#
#
#         var popup_e4401c1a167553474889e86065449ab9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47c7fc530c2b426d0786f6a7160363ed = $(`&lt;div id=&quot;html_47c7fc530c2b426d0786f6a7160363ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e4401c1a167553474889e86065449ab9.setContent(html_47c7fc530c2b426d0786f6a7160363ed);
#
#
#
#         marker_e80fdd4f7b9692c6903c94dd756e4ae9.bindPopup(popup_e4401c1a167553474889e86065449ab9)
#         ;
#
#
#
#
#             marker_cluster_259ccda3c4d018396226a94d3ce98438.addTo(map_e8d4cbceb1abb5f182ad74b38ec9658c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1819dc5f8204e456ad436db670630cfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1819dc5f8204e456ad436db670630cfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1819dc5f8204e456ad436db670630cfd = L.map(
#                 &quot;map_1819dc5f8204e456ad436db670630cfd&quot;,
#                 {
#                     center: [1.32, -8.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f9490bfa5d5fc4312a36a87acd1b816 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1f9490bfa5d5fc4312a36a87acd1b816.addTo(map_1819dc5f8204e456ad436db670630cfd);
#
#
#             var marker_cluster_e8df0780022bd5b5f92682b4c2d25fda = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_e8df0780022bd5b5f92682b4c2d25fda.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_ab95f78c692a8b8a690e37bc3ce4b42a = L.marker(
#                 [89.0, -31.0],
#                 {}
#             ).addTo(marker_cluster_e8df0780022bd5b5f92682b4c2d25fda);
#
#
#         var popup_e8c8e5a4a25cf5af6e67e4dc0658ec42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07950f8f67fc1ef725651cf25d912c5c = $(`&lt;div id=&quot;html_07950f8f67fc1ef725651cf25d912c5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-31&lt;br&gt;lat:89&lt;/div&gt;`)[0];
#                 popup_e8c8e5a4a25cf5af6e67e4dc0658ec42.setContent(html_07950f8f67fc1ef725651cf25d912c5c);
#
#
#
#         marker_ab95f78c692a8b8a690e37bc3ce4b42a.bindPopup(popup_e8c8e5a4a25cf5af6e67e4dc0658ec42)
#         ;
#
#
#
#
#             var marker_aa0a79c481b916f376e89304622e18fe = L.marker(
#                 [61.0, 79.0],
#                 {}
#             ).addTo(marker_cluster_e8df0780022bd5b5f92682b4c2d25fda);
#
#
#         var popup_6edb320c9aaf8bb94e2e08119234819b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a1f842030951a444a4d9230a4563435 = $(`&lt;div id=&quot;html_2a1f842030951a444a4d9230a4563435&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:79&lt;br&gt;lat:61&lt;/div&gt;`)[0];
#                 popup_6edb320c9aaf8bb94e2e08119234819b.setContent(html_2a1f842030951a444a4d9230a4563435);
#
#
#
#         marker_aa0a79c481b916f376e89304622e18fe.bindPopup(popup_6edb320c9aaf8bb94e2e08119234819b)
#         ;
#
#
#
#
#             var marker_65789766c79e56209ac5db51ffc123b2 = L.marker(
#                 [39.0, -102.0],
#                 {}
#             ).addTo(marker_cluster_e8df0780022bd5b5f92682b4c2d25fda);
#
#
#         var popup_a47fbe8265d0a93304f5f19cb97e3eee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42cc2b8b8ecff546dfeedc83afbaaf0a = $(`&lt;div id=&quot;html_42cc2b8b8ecff546dfeedc83afbaaf0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-102&lt;br&gt;lat:39&lt;/div&gt;`)[0];
#                 popup_a47fbe8265d0a93304f5f19cb97e3eee.setContent(html_42cc2b8b8ecff546dfeedc83afbaaf0a);
#
#
#
#         marker_65789766c79e56209ac5db51ffc123b2.bindPopup(popup_a47fbe8265d0a93304f5f19cb97e3eee)
#         ;
#
#
#
#
#             var marker_b852c6a32fa85b3f8798e0fce1e6399a = L.marker(
#                 [-59.0, 52.0],
#                 {}
#             ).addTo(marker_cluster_e8df0780022bd5b5f92682b4c2d25fda);
#
#
#         var popup_10a4ece961d26df6c24d5116cdc657cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d128a2afacad97bc653a98f1701a6370 = $(`&lt;div id=&quot;html_d128a2afacad97bc653a98f1701a6370&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:52&lt;br&gt;lat:-59&lt;/div&gt;`)[0];
#                 popup_10a4ece961d26df6c24d5116cdc657cb.setContent(html_d128a2afacad97bc653a98f1701a6370);
#
#
#
#         marker_b852c6a32fa85b3f879

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9333f92acc14e05f0b9258090d2b1470 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9333f92acc14e05f0b9258090d2b1470&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9333f92acc14e05f0b9258090d2b1470 = L.map(
#                 &quot;map_9333f92acc14e05f0b9258090d2b1470&quot;,
#                 {
#                     center: [1.32, -8.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df7972c428e7461507f626de3c716ff7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_df7972c428e7461507f626de3c716ff7.addTo(map_9333f92acc14e05f0b9258090d2b1470);
#
#
#             var marker_cluster_84947b42caacac72f025f0066eb12be8 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8f4734b1e3c317d70aff36b2310c8e1d = L.marker(
#                 [89.0, -31.0],
#                 {}
#             ).addTo(marker_cluster_84947b42caacac72f025f0066eb12be8);
#
#
#         var popup_f90c57145cfb95cd26d4b0738bf3a902 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6502478b7250196be8847f4b9627ac42 = $(`&lt;div id=&quot;html_6502478b7250196be8847f4b9627ac42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-31&lt;br&gt;lat:89&lt;/div&gt;`)[0];
#                 popup_f90c57145cfb95cd26d4b0738bf3a902.setContent(html_6502478b7250196be8847f4b9627ac42);
#
#
#
#         marker_8f4734b1e3c317d70aff36b2310c8e1d.bindPopup(popup_f90c57145cfb95cd26d4b0738bf3a902)
#         ;
#
#
#
#
#             var marker_c9e939a3edd60930e6c0a96090049d2e = L.marker(
#                 [61.0, 79.0],
#                 {}
#             ).addTo(marker_cluster_84947b42caacac72f025f0066eb12be8);
#
#
#         var popup_15d5e18b26d7db185cda7a599b6f285c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6605405c6d607f332b49270c4b42d5df = $(`&lt;div id=&quot;html_6605405c6d607f332b49270c4b42d5df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:79&lt;br&gt;lat:61&lt;/div&gt;`)[0];
#                 popup_15d5e18b26d7db185cda7a599b6f285c.setContent(html_6605405c6d607f332b49270c4b42d5df);
#
#
#
#         marker_c9e939a3edd60930e6c0a96090049d2e.bindPopup(popup_15d5e18b26d7db185cda7a599b6f285c)
#         ;
#
#
#
#
#             var marker_eebddb668027e929c472aa16cfe239dc = L.marker(
#                 [39.0, -102.0],
#                 {}
#             ).addTo(marker_cluster_84947b42caacac72f025f0066eb12be8);
#
#
#         var popup_424bdf7591fa75645dd3c85f0951b696 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06098496de8131c1105be8391958cad1 = $(`&lt;div id=&quot;html_06098496de8131c1105be8391958cad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-102&lt;br&gt;lat:39&lt;/div&gt;`)[0];
#                 popup_424bdf7591fa75645dd3c85f0951b696.setContent(html_06098496de8131c1105be8391958cad1);
#
#
#
#         marker_eebddb668027e929c472aa16cfe239dc.bindPopup(popup_424bdf7591fa75645dd3c85f0951b696)
#         ;
#
#
#
#
#             var marker_94c1dcc9ec2f23cda7587635db0b4fa4 = L.marker(
#                 [-59.0, 52.0],
#                 {}
#             ).addTo(marker_cluster_84947b42caacac72f025f0066eb12be8);
#
#
#         var popup_b304ef29f6f77e13c3e22bf2f977e1a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54f9f6ede7f8aeb210f825a9060de396 = $(`&lt;div id=&quot;html_54f9f6ede7f8aeb210f825a9060de396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:52&lt;br&gt;lat:-59&lt;/div&gt;`)[0];
#                 popup_b304ef29f6f77e13c3e22bf2f977e1a5.setContent(html_54f9f6ede7f8aeb210f825a9060de396);
#
#
#
#         marker_94c1dcc9ec2f23cda7587635db0b4fa4.bindPopup(popup_b304ef29f6f77e13c3e22bf2f977e1a5)
#         ;
#
#
#
#
#             var marker_fefeac1e38fec7602bccaae6b649d530 = L.marker(
#                 [23.0, 87.0],
#                 {}
#             ).addTo(marker_cluster_84947b42caacac72f025f0066eb12be8);
#
#
#         var popup_54b092d2fa1556e0fe6b0f8160a5

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a03203ff4718be44936dbcd55855c3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a03203ff4718be44936dbcd55855c3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a03203ff4718be44936dbcd55855c3f = L.map(
#                 &quot;map_3a03203ff4718be44936dbcd55855c3f&quot;,
#                 {
#                     center: [1.32, -8.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_