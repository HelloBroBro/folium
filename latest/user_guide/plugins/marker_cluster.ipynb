# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7fc54e491295922287486d0adfb7e5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7fc54e491295922287486d0adfb7e5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7fc54e491295922287486d0adfb7e5a = L.map(
#                 &quot;map_c7fc54e491295922287486d0adfb7e5a&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11da25342c27f98f52adba9c9bee47d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_11da25342c27f98f52adba9c9bee47d3.addTo(map_c7fc54e491295922287486d0adfb7e5a);
#
#
#             var marker_cluster_77f2f156d01b2cd19d46084d3bf33336 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_68625ca9be2977a7a5a5fd84bc854b82 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_77f2f156d01b2cd19d46084d3bf33336);
#
#
#             var icon_448f08b9c6e24260fd365e0d43b93d4f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68625ca9be2977a7a5a5fd84bc854b82.setIcon(icon_448f08b9c6e24260fd365e0d43b93d4f);
#
#
#         var popup_5a98b536be5d09d86041fc19c35da559 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53df072212ae822b500058d6efbe94fb = $(`&lt;div id=&quot;html_53df072212ae822b500058d6efbe94fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_5a98b536be5d09d86041fc19c35da559.setContent(html_53df072212ae822b500058d6efbe94fb);
#
#
#
#         marker_68625ca9be2977a7a5a5fd84bc854b82.bindPopup(popup_5a98b536be5d09d86041fc19c35da559)
#         ;
#
#
#
#
#             var marker_457028142a3c2cd6e7f9b539e672706a = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_77f2f156d01b2cd19d46084d3bf33336);
#
#
#             var icon_c055e48a7b11e650c398a463c8abce75 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_457028142a3c2cd6e7f9b539e672706a.setIcon(icon_c055e48a7b11e650c398a463c8abce75);
#
#
#         var popup_8bd907045f441d89859ee2a0b428eed8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a63e89dafef438899ac053a4b442c5ef = $(`&lt;div id=&quot;html_a63e89dafef438899ac053a4b442c5ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8bd907045f441d89859ee2a0b428eed8.setContent(html_a63e89dafef438899ac053a4b442c5ef);
#
#
#
#         marker_457028142a3c2cd6e7f9b539e672706a.bindPopup(popup_8bd907045f441d89859ee2a0b428eed8)
#         ;
#
#
#
#
#             var marker_86738c2090b68c4289e6e4d847e07cd4 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_77f2f156d01b2cd19d46084d3bf33336);
#
#
#         var popup_e88f765b000c649d046bfb48c4d9656e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad68cb735a8e703184468ce23512ba49 = $(`&lt;div id=&quot;html_ad68cb735a8e703184468ce23512ba49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e88f765b000c649d046bfb48c4d9656e.setContent(html_ad68cb735a8e703184468ce23512ba49);
#
#
#
#         marker_86738c2090b68c4289e6e4d847e07cd4.bindPopup(popup_e88f765b000c649d046bfb48c4d9656e)
#         ;
#
#
#
#
#             marker_cluster_77f2f156d01b2cd19d46084d3bf33336.addTo(map_c7fc54e491295922287486d0adfb7e5a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullsc

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec4ba953962042613c45ef0e984018f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec4ba953962042613c45ef0e984018f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec4ba953962042613c45ef0e984018f3 = L.map(
#                 &quot;map_ec4ba953962042613c45ef0e984018f3&quot;,
#                 {
#                     center: [-4.46, -8.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf61038cefa27dd44fae494843c21385 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bf61038cefa27dd44fae494843c21385.addTo(map_ec4ba953962042613c45ef0e984018f3);
#
#
#             var marker_cluster_1c8f1fe5f462651f1eaaf10f2caec559 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_1c8f1fe5f462651f1eaaf10f2caec559.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_5c9ca323be0138dcae5495e60a287e01 = L.marker(
#                 [-88.0, 14.0],
#                 {}
#             ).addTo(marker_cluster_1c8f1fe5f462651f1eaaf10f2caec559);
#
#
#         var popup_baf2566bb8955f2584ab9554e7673072 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cd202908eca1a45f2b4d27be5e37ef5 = $(`&lt;div id=&quot;html_3cd202908eca1a45f2b4d27be5e37ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:14&lt;br&gt;lat:-88&lt;/div&gt;`)[0];
#                 popup_baf2566bb8955f2584ab9554e7673072.setContent(html_3cd202908eca1a45f2b4d27be5e37ef5);
#
#
#
#         marker_5c9ca323be0138dcae5495e60a287e01.bindPopup(popup_baf2566bb8955f2584ab9554e7673072)
#         ;
#
#
#
#
#             var marker_25fbe406a0d0c3bdef9f2baa59f49705 = L.marker(
#                 [47.0, -117.0],
#                 {}
#             ).addTo(marker_cluster_1c8f1fe5f462651f1eaaf10f2caec559);
#
#
#         var popup_12c43fd1059baf5cef9cc683a4403f13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c790e0029c96b21010ee11673cde1b58 = $(`&lt;div id=&quot;html_c790e0029c96b21010ee11673cde1b58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-117&lt;br&gt;lat:47&lt;/div&gt;`)[0];
#                 popup_12c43fd1059baf5cef9cc683a4403f13.setContent(html_c790e0029c96b21010ee11673cde1b58);
#
#
#
#         marker_25fbe406a0d0c3bdef9f2baa59f49705.bindPopup(popup_12c43fd1059baf5cef9cc683a4403f13)
#         ;
#
#
#
#
#             var marker_a73ba36eb076bc79d8e4b42086e56b09 = L.marker(
#                 [1.0, 88.0],
#                 {}
#             ).addTo(marker_cluster_1c8f1fe5f462651f1eaaf10f2caec559);
#
#
#         var popup_9ee71f84694805559048390bed424a52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_180fcaaf0f54996df6df544b7779da49 = $(`&lt;div id=&quot;html_180fcaaf0f54996df6df544b7779da49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:88&lt;br&gt;lat:1&lt;/div&gt;`)[0];
#                 popup_9ee71f84694805559048390bed424a52.setContent(html_180fcaaf0f54996df6df544b7779da49);
#
#
#
#         marker_a73ba36eb076bc79d8e4b42086e56b09.bindPopup(popup_9ee71f84694805559048390bed424a52)
#         ;
#
#
#
#
#             var marker_cb895bb424fc3d626154a80b0eb692d6 = L.marker(
#                 [-61.0, -164.0],
#                 {}
#             ).addTo(marker_cluster_1c8f1fe5f462651f1eaaf10f2caec559);
#
#
#         var popup_b8fc842d785bff58f0aacbe2c58f07b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2f101cd6a99c128d7b4294cd71dd6f5 = $(`&lt;div id=&quot;html_e2f101cd6a99c128d7b4294cd71dd6f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-164&lt;br&gt;lat:-61&lt;/div&gt;`)[0];
#                 popup_b8fc842d785bff58f0aacbe2c58f07b6.setContent(html_e2f101cd6a99c128d7b4294cd71dd6f5);
#
#
#
#         marker_cb895bb424fc3d626154a80

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eff1fed2eabafd754f0815161f7db3c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eff1fed2eabafd754f0815161f7db3c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eff1fed2eabafd754f0815161f7db3c1 = L.map(
#                 &quot;map_eff1fed2eabafd754f0815161f7db3c1&quot;,
#                 {
#                     center: [-4.46, -8.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aec3a46105f75bb4f7404b88b356290e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aec3a46105f75bb4f7404b88b356290e.addTo(map_eff1fed2eabafd754f0815161f7db3c1);
#
#
#             var marker_cluster_46c558e86a0fc5bb6a524080bb5a0051 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_184ce52ffbf20c328c78791f2572a5d7 = L.marker(
#                 [-88.0, 14.0],
#                 {}
#             ).addTo(marker_cluster_46c558e86a0fc5bb6a524080bb5a0051);
#
#
#         var popup_6c1ff6dfb0b7bc1a74df740d116a2bfb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1633dcb95d050e8631386b27698bcf9d = $(`&lt;div id=&quot;html_1633dcb95d050e8631386b27698bcf9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:14&lt;br&gt;lat:-88&lt;/div&gt;`)[0];
#                 popup_6c1ff6dfb0b7bc1a74df740d116a2bfb.setContent(html_1633dcb95d050e8631386b27698bcf9d);
#
#
#
#         marker_184ce52ffbf20c328c78791f2572a5d7.bindPopup(popup_6c1ff6dfb0b7bc1a74df740d116a2bfb)
#         ;
#
#
#
#
#             var marker_599b04fe445c911c7a083f96ffe584e2 = L.marker(
#                 [47.0, -117.0],
#                 {}
#             ).addTo(marker_cluster_46c558e86a0fc5bb6a524080bb5a0051);
#
#
#         var popup_204000cc4ef02f97b5630d1dc4842ed1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5aefc8cea735adeaed3c70153fe1181e = $(`&lt;div id=&quot;html_5aefc8cea735adeaed3c70153fe1181e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-117&lt;br&gt;lat:47&lt;/div&gt;`)[0];
#                 popup_204000cc4ef02f97b5630d1dc4842ed1.setContent(html_5aefc8cea735adeaed3c70153fe1181e);
#
#
#
#         marker_599b04fe445c911c7a083f96ffe584e2.bindPopup(popup_204000cc4ef02f97b5630d1dc4842ed1)
#         ;
#
#
#
#
#             var marker_d98769e766e4fba3c4feda8d2e87311e = L.marker(
#                 [1.0, 88.0],
#                 {}
#             ).addTo(marker_cluster_46c558e86a0fc5bb6a524080bb5a0051);
#
#
#         var popup_5d908f9f1e1dec33ed21fa7c075f1f83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0ad52f8ad8e383bc9fd4aadc37abbc8 = $(`&lt;div id=&quot;html_a0ad52f8ad8e383bc9fd4aadc37abbc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:88&lt;br&gt;lat:1&lt;/div&gt;`)[0];
#                 popup_5d908f9f1e1dec33ed21fa7c075f1f83.setContent(html_a0ad52f8ad8e383bc9fd4aadc37abbc8);
#
#
#
#         marker_d98769e766e4fba3c4feda8d2e87311e.bindPopup(popup_5d908f9f1e1dec33ed21fa7c075f1f83)
#         ;
#
#
#
#
#             var marker_668d03870c6ef1af85739ea4a4bc338f = L.marker(
#                 [-61.0, -164.0],
#                 {}
#             ).addTo(marker_cluster_46c558e86a0fc5bb6a524080bb5a0051);
#
#
#         var popup_0c55db3e8328b2a7b69fa4c76d56bb5f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_058c61c7f5684772654f26f881f729fb = $(`&lt;div id=&quot;html_058c61c7f5684772654f26f881f729fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-164&lt;br&gt;lat:-61&lt;/div&gt;`)[0];
#                 popup_0c55db3e8328b2a7b69fa4c76d56bb5f.setContent(html_058c61c7f5684772654f26f881f729fb);
#
#
#
#         marker_668d03870c6ef1af85739ea4a4bc338f.bindPopup(popup_0c55db3e8328b2a7b69fa4c76d56bb5f)
#         ;
#
#
#
#
#             var marker_4a3851374ba0148c3dc087b82555f85a = L.marker(
#                 [-51.0, -86.0],
#                 {}
#             ).addTo(marker_cluster_46c558e86a0fc5bb6a524080bb5a0051);
#
#
#         var popup_b8a070a96625d3111a49f5b1cfc279

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ad4f6f9c58aa0f77ebe03792865f212 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ad4f6f9c58aa0f77ebe03792865f212&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ad4f6f9c58aa0f77ebe03792865f212 = L.map(
#                 &quot;map_6ad4f6f9c58aa0f77ebe03792865f212&quot;,
#                 {
#                     center: [-4.46, -8.66],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_359d1bc4c0a84ac1fe3793031510f0ec = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_359d1bc4c0a84ac1fe3793031510f0ec.addTo(map_6ad4f6f9c58aa0f77ebe03792865f212);
#
#
#             var fast_marker_cluster_55bb9dc36f0958048ea06df0b8a53e45 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[